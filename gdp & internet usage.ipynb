# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#3) see above

# %%
# %matplotlib inline

# %%
#4) %matplotlib inline

# %%
gdp_df = pd.read_csv('../data/gdp_percapita.csv', nrows = 6606)

# %%
#5) gdp_df = pd.read_csv('../data/gdp_percapita.csv', nrows = 6606)

# %%
gdp_df.head(6)
# Out:
#   Country or Area  Year        Value  Value Footnotes
# 0     Afghanistan  2018  2190.240321              NaN
# 1     Afghanistan  2017  2202.570851              NaN
# 2     Afghanistan  2016  2200.764487              NaN
# 3     Afghanistan  2015  2212.750899              NaN
# 4     Afghanistan  2014  2249.253738              NaN
# 5     Afghanistan  2013  2264.317575              NaN

# %%
internet_df = pd.read_csv('../data/internet_use.csv', nrows = 4495)

# %%
#6) internet_df = pd.read_csv('../data/internet_use.csv', nrows = 4495)

# %%
internet_df.head(6)
# Out:
#   Country or Area  Year     Value  Value Footnotes
# 0     Afghanistan  2014  6.390000              NaN
# 1     Afghanistan  2013  5.900000              NaN
# 2     Afghanistan  2012  5.454545              NaN
# 3     Afghanistan  2011  5.000000              NaN
# 4     Afghanistan  2010  4.000000              NaN
# 5     Afghanistan  2009  3.550000              NaN

# %%
print(gdp_df.shape)
# Out:
# (6606, 4)

# %%
#7) gdp_df.shape, 6606 rows, 4 columns

# %%
print(internet_df.shape)
# Out:
# (4495, 4)

# %%
#7) internet_df.shape, 4495 rows,4 columns

# %%
gdp_df.dtypes
# Out:
# Country or Area     object
# Year                 int64
# Value              float64
# Value Footnotes    float64
# dtype: object

# %%
internet_df.dtypes
# Out:
# Country or Area     object
# Year                 int64
# Value              float64
# Value Footnotes    float64
# dtype: object

# %%
#8) gdp_df.dtypes, internet_df.dtypes, can use .info as well

# %%
gdp_df.tail(10)
# Out:
#      Country or Area  Year        Value  Value Footnotes
# 6596        Zimbabwe  1999  3600.849291              NaN
# 6597        Zimbabwe  1998  3653.920016              NaN
# 6598        Zimbabwe  1997  3580.048793              NaN
# 6599        Zimbabwe  1996  3520.430146              NaN
# 6600        Zimbabwe  1995  3226.413930              NaN
# 6601        Zimbabwe  1994  3263.934978              NaN
# 6602        Zimbabwe  1993  3033.504852              NaN
# 6603        Zimbabwe  1992  3054.889178              NaN
# 6604        Zimbabwe  1991  3426.598094              NaN
# 6605        Zimbabwe  1990  3324.348171              NaN

# %%
#9) gdp_df.tail(10)

# %%
internet_df.tail(10)
# Out:
#      Country or Area  Year     Value  Value Footnotes
# 4485        Zimbabwe  2002  3.994356              NaN
# 4486        Zimbabwe  2001  0.799846              NaN
# 4487        Zimbabwe  2000  0.401434              NaN
# 4488        Zimbabwe  1999  0.161676              NaN
# 4489        Zimbabwe  1998  0.081648              NaN
# 4490        Zimbabwe  1997  0.033080              NaN
# 4491        Zimbabwe  1996  0.016790              NaN
# 4492        Zimbabwe  1995  0.007684              NaN
# 4493        Zimbabwe  1994  0.001739              NaN
# 4494        Zimbabwe  1990  0.000000              NaN

# %%
#9) internet_df.tail(10)

# %%
gdp_df = gdp_df.drop(columns = ['Value Footnotes'])

# %%
#10) gdp_df = gdp_df.drop(columns = ['Value Footnotes'])

# %%
internet_df = internet_df.drop(columns = ['Value Footnotes'])

# %%
#10) internet_df = internet_df.drop(columns = ['Value Footnotes'])

# %%
gdp_df.head(20)
# Out:
#    Country or Area  Year         Value
# 0      Afghanistan  2018   2190.240321
# 1      Afghanistan  2017   2202.570851
# 2      Afghanistan  2016   2200.764487
# 3      Afghanistan  2015   2212.750899
# 4      Afghanistan  2014   2249.253738
# 5      Afghanistan  2013   2264.317575
# 6      Afghanistan  2012   2220.481526
# 7      Afghanistan  2011   2037.608607
# 8      Afghanistan  2010   2093.743565
# 9      Afghanistan  2009   1881.777626
# 10     Afghanistan  2008   1587.792070
# 11     Afghanistan  2007   1562.876516
# 12     Afghanistan  2006   1407.708041
# 13     Afghanistan  2005   1376.686376
# 14     Afghanistan  2004   1284.127338
# 15     Afghanistan  2003   1322.141328
# 16     Afghanistan  2002   1272.900914
# 17         Albania  2018  13601.303380
# 18         Albania  2017  13037.010020
# 19         Albania  2016  12547.928080

# %%
gdp_df.columns = ['Country', 'Year', 'GDP_Per_Capita']

# %%
#11) gdp_df.columns = ['Country', 'Year', 'GDP_Per_Capita']

# %%
internet_df.head(5)
# Out:
#   Country or Area  Year     Value
# 0     Afghanistan  2014  6.390000
# 1     Afghanistan  2013  5.900000
# 2     Afghanistan  2012  5.454545
# 3     Afghanistan  2011  5.000000
# 4     Afghanistan  2010  4.000000

# %%
internet_df.columns = ['Country', 'Year', 'Internet_Users_Pct']

# %%
#12) internet_df.columns = ['Country', 'Year', 'Internet_Users_Pct']

# %%
internet_df.head(5)
# Out:
#        Country  Year  Internet_Users_Pct
# 0  Afghanistan  2014            6.390000
# 1  Afghanistan  2013            5.900000
# 2  Afghanistan  2012            5.454545
# 3  Afghanistan  2011            5.000000
# 4  Afghanistan  2010            4.000000

# %%
internet_df.tail(5)
# Out:
#        Country  Year  Internet_Users_Pct
# 4490  Zimbabwe  1997            0.033080
# 4491  Zimbabwe  1996            0.016790
# 4492  Zimbabwe  1995            0.007684
# 4493  Zimbabwe  1994            0.001739
# 4494  Zimbabwe  1990            0.000000

# %%
gdp_df.head(5)
# Out:
#        Country  Year  GDP_Per_Capita
# 0  Afghanistan  2018     2190.240321
# 1  Afghanistan  2017     2202.570851
# 2  Afghanistan  2016     2200.764487
# 3  Afghanistan  2015     2212.750899
# 4  Afghanistan  2014     2249.253738

# %%
gdp_df.tail(5)
# Out:
#        Country  Year  GDP_Per_Capita
# 6601  Zimbabwe  1994     3263.934978
# 6602  Zimbabwe  1993     3033.504852
# 6603  Zimbabwe  1992     3054.889178
# 6604  Zimbabwe  1991     3426.598094
# 6605  Zimbabwe  1990     3324.348171

# %%
gdp_and_internet_use = pd.merge(gdp_df, internet_df, left_on = ['Country', 'Year'], right_on = ['Country', 'Year'], how = 'outer')

# %%
#13) gdp_and_internet_use = pd.merge(gdp_df, internet_df, left_on = ['Country', 'Year'], right_on = ['Country', 'Year'], how = 'outer')

# %%
gdp_and_internet_use
# Out:
#           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 0     Afghanistan  2018     2190.240321                 NaN
# 1     Afghanistan  2017     2202.570851                 NaN
# 2     Afghanistan  2016     2200.764487                 NaN
# 3     Afghanistan  2015     2212.750899                 NaN
# 4     Afghanistan  2014     2249.253738            6.390000
# ...           ...   ...             ...                 ...
# 7659        Yemen  1999             NaN            0.056629
# 7660        Yemen  1998             NaN            0.023323
# 7661        Yemen  1997             NaN            0.015025
# 7662        Yemen  1996             NaN            0.000621
# 7663        Yemen  1990             NaN            0.000000
#
# [7664 rows x 4 columns]

# %%
gdp_and_internet_use.head(5)
# Out:
#        Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 0  Afghanistan  2018     2190.240321                 NaN
# 1  Afghanistan  2017     2202.570851                 NaN
# 2  Afghanistan  2016     2200.764487                 NaN
# 3  Afghanistan  2015     2212.750899                 NaN
# 4  Afghanistan  2014     2249.253738                6.39

# %%
#14) gdp_and_internet_use.head(5)

# %%
gdp_and_internet_use.shape
# Out:
# (7664, 4)

# %%
gdp_and_internet_use.tail(5)
# Out:
#      Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 7659   Yemen  1999             NaN            0.056629
# 7660   Yemen  1998             NaN            0.023323
# 7661   Yemen  1997             NaN            0.015025
# 7662   Yemen  1996             NaN            0.000621
# 7663   Yemen  1990             NaN            0.000000

# %%
#15) gdp_and_internet_use.tail(5)

# %%
gdp_and_internet_use_subset = gdp_and_internet_use[gdp_and_internet_use.Year.isin(['2004', '2009', '2014'])]

# %%
gdp_and_internet_use_subset.head(5)
# Out:
#         Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 4   Afghanistan  2014     2249.253738            6.390000
# 9   Afghanistan  2009     1881.777626            3.550000
# 14  Afghanistan  2004     1284.127338            0.105809
# 21      Albania  2014    11828.232260           60.100000
# 26      Albania  2009    10528.778100           41.200000

# %%
gdp_internet_2004 = gdp_and_internet_use_subset[gdp_and_internet_use_subset.Year.isin(['2004'])]

# %%
#16) gdp_internet_2004 = gdp_and_internet_use_subset[gdp_and_internet_use_subset.Year.isin(['2004'])]

# %%
gdp_internet_2004.head(5)
# Out:
#                  Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 14           Afghanistan  2004     1284.127338            0.105809
# 31               Albania  2004     7738.542836            2.420388
# 60               Algeria  2004     9898.310490            4.634475
# 89                Angola  2004     5568.959139            0.464815
# 118  Antigua and Barbuda  2004    18742.463740           24.266544

# %%
gdp_internet_2009 = gdp_and_internet_use_subset[gdp_and_internet_use_subset.Year.isin(['2009'])]

# %%
#16) gdp_internet_2009 = gdp_and_internet_use_subset[gdp_and_internet_use_subset.Year.isin(['2009'])]

# %%
gdp_internet_2009.head(5)
# Out:
#                  Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 9            Afghanistan  2009     1881.777626                3.55
# 26               Albania  2009    10528.778100               41.20
# 55               Algeria  2009    10610.711400               11.23
# 84                Angola  2009     7610.310423                6.00
# 113  Antigua and Barbuda  2009    19989.092910               42.00

# %%
gdp_internet_2014 = gdp_and_internet_use_subset[gdp_and_internet_use_subset.Year.isin(['2014'])]

# %%
#16) gdp_internet_2014 = gdp_and_internet_use_subset[gdp_and_internet_use_subset.Year.isin(['2014'])]

# %%
gdp_internet_2014.head(5)
# Out:
#                  Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 4            Afghanistan  2014     2249.253738                6.39
# 21               Albania  2014    11828.232260               60.10
# 50               Algeria  2014    11329.428690               18.09
# 79                Angola  2014     8239.832077               21.26
# 108  Antigua and Barbuda  2014    18104.241470               64.00

# %%
gdp_internet_2014.max(axis=0)['Internet_Users_Pct']
# Out:
# 98.16

# %%
gdp_internet_2014.sort_values(by = 'Internet_Users_Pct', ascending = False)
# Out:
#                   Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 2507              Iceland  2014    49911.069820               98.16
# 6649              Bermuda  2014             NaN               96.80
# 4461               Norway  2014    61308.763730               96.30
# 1374              Denmark  2014    52172.606430               95.99
# 6609              Andorra  2014             NaN               95.90
# ...                   ...   ...             ...                 ...
# 6179               Tuvalu  2014     3455.741510                 NaN
# 6353  Upper middle income  2014    14271.692390                 NaN
# 6469              Vietnam  2014     6098.489609                 NaN
# 6498   West Bank and Gaza  2014     5499.415939                 NaN
# 6523                World  2014    15181.246950                 NaN
#
# [277 rows x 4 columns]

# %%
#18) gdp_internet_2014.sort_values(by = 'Internet_Users_Pct', ascending = False), 98.16% - Iceland

# %%
gdp_internet_2014.sort_values(by = 'Internet_Users_Pct', ascending = True)
# Out:
#                           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 6838  Dem. People's Rep. of Korea  2014             NaN                0.00
# 6896                      Eritrea  2014             NaN                0.99
# 5978                  Timor-Leste  2014     3264.739189                1.14
# 770                       Burundi  2014      886.235777                1.38
# 7433                      Somalia  2014             NaN                1.63
# ...                           ...   ...             ...                 ...
# 6179                       Tuvalu  2014     3455.741510                 NaN
# 6353          Upper middle income  2014    14271.692390                 NaN
# 6469                      Vietnam  2014     6098.489609                 NaN
# 6498           West Bank and Gaza  2014     5499.415939                 NaN
# 6523                        World  2014    15181.246950                 NaN
#
# [277 rows x 4 columns]

# %%
#19) gdp_internet_2014.sort_values(by = 'Internet_Users_Pct', ascending = False), 0% - North Korea

# %%
gdp_internet_2004.sort_values(by = 'Internet_Users_Pct', ascending = False)
# Out:
#                   Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 5785               Sweden  2004    45029.814340               83.89
# 2517              Iceland  2004    45380.965460               83.88
# 1384              Denmark  2004    50566.988090               80.93
# 4471               Norway  2004    59647.501410               77.69
# 7159      Korea (Rep. of)  2004             NaN               72.70
# ...                   ...   ...             ...                 ...
# 6189               Tuvalu  2004     3341.738017                 NaN
# 6363  Upper middle income  2004     8561.878030                 NaN
# 6479              Vietnam  2004     3689.732423                 NaN
# 6508   West Bank and Gaza  2004     4113.246936                 NaN
# 6533                World  2004    12070.457340                 NaN
#
# [276 rows x 4 columns]

# %%
#20) gdp_internet_2004.sort_values(by = 'Internet_Users_Pct', ascending = False)

# %%
gdp_internet_2004.sort_values(by = 'Internet_Users_Pct', ascending = True)
# Out:
#                           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 6847  Dem. People's Rep. of Korea  2004             NaN            0.000000
# 4166                      Myanmar  2004     1696.881760            0.024337
# 3395                      Liberia  2004     1181.546158            0.031011
# 5843                   Tajikistan  2004     1737.743630            0.077480
# 14                    Afghanistan  2004     1284.127338            0.105809
# ...                           ...   ...             ...                 ...
# 6189                       Tuvalu  2004     3341.738017                 NaN
# 6363          Upper middle income  2004     8561.878030                 NaN
# 6479                      Vietnam  2004     3689.732423                 NaN
# 6508           West Bank and Gaza  2004     4113.246936                 NaN
# 6533                        World  2004    12070.457340                 NaN
#
# [276 rows x 4 columns]

# %%
gdp_internet_2009.sort_values(by = 'Internet_Users_Pct', ascending = False)
# Out:
#                   Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 2512              Iceland  2009    48428.312440               93.00
# 4466               Norway  2009    60620.334500               92.08
# 5780               Sweden  2009    46185.526530               91.00
# 4263          Netherlands  2009    51850.500540               89.63
# 3540           Luxembourg  2009   105077.951500               87.31
# ...                   ...   ...             ...                 ...
# 5954           The Gambia  2009     2283.183556                 NaN
# 6358  Upper middle income  2009    11209.044720                 NaN
# 6474              Vietnam  2009     4830.304958                 NaN
# 6503   West Bank and Gaza  2009     4721.086034                 NaN
# 6528                World  2009    13389.627690                 NaN
#
# [277 rows x 4 columns]

# %%
#20) gdp_internet_2009.sort_values(by = 'Internet_Users_Pct', ascending = False)

# %%
gdp_internet_2009.sort_values(by = 'Internet_Users_Pct', ascending = True)
# Out:
#                           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 6842  Dem. People's Rep. of Korea  2009             NaN            0.000000
# 5983                  Timor-Leste  2009     2724.834868            0.185252
# 4161                      Myanmar  2009     2874.780227            0.220000
# 5225                 Sierra Leone  2009     1372.392285            0.260000
# 862                      Cambodia  2009     2603.583778            0.530000
# ...                           ...   ...             ...                 ...
# 5954                   The Gambia  2009     2283.183556                 NaN
# 6358          Upper middle income  2009    11209.044720                 NaN
# 6474                      Vietnam  2009     4830.304958                 NaN
# 6503           West Bank and Gaza  2009     4721.086034                 NaN
# 6528                        World  2009    13389.627690                 NaN
#
# [277 rows x 4 columns]

# %%
#20) gdp_internet_2009.sort_values(by = 'Internet_Users_Pct', ascending = True)

# %%
gdp_internet_2014.sort_values(by = 'GDP_Per_Capita', ascending = False)
# Out:
#                     Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 3564       Macao SAR, China  2014    156514.13380                 NaN
# 3535             Luxembourg  2014    108911.34890               94.67
# 4934                  Qatar  2014     97938.30523               91.49
# 5249              Singapore  2014     87808.66316               82.00
# 970          Cayman Islands  2014     66195.47559               74.10
# ...                     ...   ...             ...                 ...
# 7520     T.F.Y.R. Macedonia  2014             NaN               68.06
# 7578              Venezuela  2014             NaN               57.00
# 7602               Viet Nam  2014             NaN               48.31
# 7622  Virgin Islands (U.S.)  2014             NaN               50.07
# 7644                  Yemen  2014             NaN               22.55
#
# [277 rows x 4 columns]

# %%
#21) gdp_internet_2014.sort_values(by = 'GDP_Per_Capita', ascending = False), Macao - 156514.13380

# %%
gdp_internet_2014.sort_values(by = 'GDP_Per_Capita', ascending = True)
# Out:
#                        Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 983   Central African Republic  2014      822.610458                 NaN
# 770                    Burundi  2014      886.235777                1.38
# 3622                    Malawi  2014     1027.208496                5.83
# 1345           Dem. Rep. Congo  2014     1029.790785                 NaN
# 4345                     Niger  2014     1126.153622                1.95
# ...                        ...   ...             ...                 ...
# 7520        T.F.Y.R. Macedonia  2014             NaN               68.06
# 7578                 Venezuela  2014             NaN               57.00
# 7602                  Viet Nam  2014             NaN               48.31
# 7622     Virgin Islands (U.S.)  2014             NaN               50.07
# 7644                     Yemen  2014             NaN               22.55
#
# [277 rows x 4 columns]

# %%
#22) gdp_internet_2014.sort_values(by = 'GDP_Per_Capita', ascending = False), Central African Republic - 822.610458

# %%
plt.scatter(x = 'Internet_Users_Pct', y = 'GDP_Per_Capita', data = gdp_internet_2004)
plt.xlabel('Internet_Users_Pct')
plt.ylabel('GDP_Per_Capita');

# %%
# 23a) plt.scatter(x = 'Internet_Users_Pct', y = 'GDP_Per_Capita', data = gdp_internet_2004)
#      plt.xlabel('Internet_Users_Pct')
#      plt.ylabel('GDP_Per_Capita');

# %%
plt.scatter(x = 'Internet_Users_Pct', y = 'GDP_Per_Capita', data = gdp_internet_2009)
plt.xlabel('Internet_Users_Pct')
plt.ylabel('GDP_Per_Capita');

# %%
# 23b) plt.scatter(x = 'Internet_Users_Pct', y = 'GDP_Per_Capita', data = gdp_internet_2009)
#      plt.xlabel('Internet_Users_Pct')
#      plt.ylabel('GDP_Per_Capita');

# %%
plt.scatter(x = 'Internet_Users_Pct', y = 'GDP_Per_Capita', data = gdp_internet_2014)
plt.xlabel('Internet_Users_Pct')
plt.ylabel('GDP_Per_Capita');

# %%
# 23c) plt.scatter(x = 'Internet_Users_Pct', y = 'GDP_Per_Capita', data = gdp_internet_2014)
#      plt.xlabel('Internet_Users_Pct')
#      plt.ylabel('GDP_Per_Capita');

# %%
#24) All 3 years show a positive correlation between internet use and gdp. The distribution gets tighter over time.

# %%
sns.distplot(gdp_internet_2014['GDP_Per_Capita'], bins=25);
# Out:
# C:\Users\17202\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#25) Yes, it only has 1 peak.

# %%
sns.distplot(gdp_internet_2014['Internet_Users_Pct'], bins=25);
# Out:
# C:\Users\17202\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#26) No, it's more bidmodal

# %%
gdp_internet_2014.sort_values(by = 'Internet_Users_Pct', ascending = False)
# Out:
#                   Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 2507              Iceland  2014    49911.069820               98.16
# 6649              Bermuda  2014             NaN               96.80
# 4461               Norway  2014    61308.763730               96.30
# 1374              Denmark  2014    52172.606430               95.99
# 6609              Andorra  2014             NaN               95.90
# ...                   ...   ...             ...                 ...
# 6179               Tuvalu  2014     3455.741510                 NaN
# 6353  Upper middle income  2014    14271.692390                 NaN
# 6469              Vietnam  2014     6098.489609                 NaN
# 6498   West Bank and Gaza  2014     5499.415939                 NaN
# 6523                World  2014    15181.246950                 NaN
#
# [277 rows x 4 columns]

# %%
#27) Iceland, Bermuda, Norway, Denmark, Andorra

# %%
top_5_internet = gdp_and_internet_use_subset[gdp_and_internet_use_subset.Country.isin(['Iceland', 'Bermuda', 'Norway', 'Denmark', 'Andorra'])]

# %%
top_5_internet.head
# Out:
# <bound method NDFrame.head of       Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 1374  Denmark  2014     52172.60643           95.990000
# 1379  Denmark  2009     50233.70269           86.840000
# 1384  Denmark  2004     50566.98809           80.930000
# 2507  Iceland  2014     49911.06982           98.160000
# 2512  Iceland  2009     48428.31244           93.000000
# 2517  Iceland  2004     45380.96546           83.880000
# 4461   Norway  2014     61308.76373           96.300000
# 4466   Norway  2009     60620.33450           92.080000
# 4471   Norway  2004     59647.50141           77.690000
# 6609  Andorra  2014             NaN           95.900000
# 6614  Andorra  2009             NaN           78.530000
# 6619  Andorra  2004             NaN           26.837954
# 6649  Bermuda  2014             NaN           96.800000
# 6654  Bermuda  2009             NaN           83.250000
# 6659  Bermuda  2004             NaN           60.990867>

# %%
#28) top_5_internet = gdp_and_internet_use_subset[gdp_and_internet_use_subset.Country.isin(['Iceland', 'Bermuda', 'Norway', 'Denmark', 'Andorra'])]

# %%
top_5_internet.head
# Out:
# <bound method NDFrame.head of       Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 1374  Denmark  2014     52172.60643           95.990000
# 1379  Denmark  2009     50233.70269           86.840000
# 1384  Denmark  2004     50566.98809           80.930000
# 2507  Iceland  2014     49911.06982           98.160000
# 2512  Iceland  2009     48428.31244           93.000000
# 2517  Iceland  2004     45380.96546           83.880000
# 4461   Norway  2014     61308.76373           96.300000
# 4466   Norway  2009     60620.33450           92.080000
# 4471   Norway  2004     59647.50141           77.690000
# 6609  Andorra  2014             NaN           95.900000
# 6614  Andorra  2009             NaN           78.530000
# 6619  Andorra  2004             NaN           26.837954
# 6649  Bermuda  2014             NaN           96.800000
# 6654  Bermuda  2009             NaN           83.250000
# 6659  Bermuda  2004             NaN           60.990867>

# %%
import seaborn as sns

# %%
difficult_question_29 = pd.DataFrame(top_5_internet)

# %%
g = sns.FacetGrid(top_5_internet, col='Country')
g.map(plt.plot, 'Year', 'Internet_Users_Pct')
g.add_legend
# Out:
# <bound method Grid.add_legend of <seaborn.axisgrid.FacetGrid object at 0x00000190B8D3E730>>
